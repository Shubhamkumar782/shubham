# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

 

data_1=pd.read_csv("D:/Users/SKuma557/OneDrive - JNJ/Desktop/SRM Last 24 Months New Hire Requests.csv")

 

data_2=pd.read_csv("D:/Users/SKuma557/OneDrive - JNJ/Desktop/SRM Last 24-36 Months New Hire Requests.csv")

 

data_3=pd.read_csv("D:/Users/SKuma557/OneDrive - JNJ/Desktop/SRM Last 36 Months New Hire Requests - Reassignments.csv")

 

data_1.shape

 

data_2.shape

 

data_3.shape

 

first_two_merged=data_1.append(data_2)

 

first_two_merged.shape

 

first_two_merged.tail()

 

first_two_merged.to_csv("first_two_merged.csv",index=False)

 

final_dataset_updated=pd.merge(first_two_merged,data_3)

 

final_dataset_updated.shape

 

final_dataset_updated.head()

 

final_dataset_updated.tail(10)

 

plt.figure(figsize=(10,10))
data = first_two_merged["item_service_item_name"].value_counts()[:20]
sns.barplot(x=data.values, y=data.index)
plt.title(f"TOP 20 items")
plt.show()

 

First_hundred_re_no=list(final_dataset_updated_new.request_number[0:100])

 

data_3[data_3['request_number'].isin(['REQ000016842514','REQ000017227744'])] 

 

data_3.columns

 

sub_part_final=final_dataset_updated_new[['request_number', 'item_number', 'task_number',
       'task_reassignment_count']]

 

sub_part_final.head()

 

pd.options.display.max_rows = 100

 

check_1=data_3[data_3['request_number'].isin(First_hundred_re_no)] 
check_1

 

pd.options.display.max_rows = 1000

 

check_2=sub_part_final[sub_part_final['request_number'].isin(First_hundred_re_no)] 
check_2

 

data_3_new=data_3.drop_duplicates()

 

data_3_new.shape

 

final_dataset_updated_new=pd.merge(first_two_merged,data_3_new)

 

final_dataset_updated_new.shape

 

first_two_merged.shape

 

final_dataset_updated_new.to_csv("final_dataset_updated_new.csv")

 

check_1.to_csv("check_1.csv")

 

check_2.to_csv("check_2.csv")
